# %% [markdown]
# # NBV Training Test
#
# Minimal test to diagnose issues

# %%
import sys
import os
print(f"Python version: {sys.version}")
print(f"Working directory: {os.getcwd()}")
print(f"Files: {os.listdir('.')}")

# %%
# Check if running on Kaggle
from pathlib import Path
IS_KAGGLE = Path("/kaggle/input").exists()
print(f"Running on Kaggle: {IS_KAGGLE}")

if IS_KAGGLE:
    print(f"Kaggle inputs: {list(Path('/kaggle/input').iterdir())}")

# %%
# Test uv installation
import subprocess
result = subprocess.run(["pip", "install", "uv"], capture_output=True, text=True)
print(result.stdout)
print(result.stderr)

# %%
# Test git clone
result = subprocess.run(
    ["git", "clone", "https://github.com/SergKurchev/article-nbv.git"],
    capture_output=True,
    text=True
)
print(result.stdout)
print(result.stderr)
print(f"\nCloned: {Path('article-nbv').exists()}")

# %%
print("Test completed successfully!")
